# %%
## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "API Key"
print(url)
# Out:
# -------------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       2 import requests
#       4 # Import the API key.
# ----> 5 from config import weather_api_key
#       7 # Import the time library and the datetime module from the datetime library
#       8 import time
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | mayumba
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | san carlos del zulia
# Processing Record 10 of Set 1 | bowen
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | vana-voidu
# City not found. Skipping...
# Processing Record 13 of Set 1 | ottawa
# Processing Record 14 of Set 1 | port blair
# Processing Record 15 of Set 1 | buluang
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | la rioja
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | saint-prosper
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | coahuayana
# Processing Record 25 of Set 1 | constitucion
# Processing Record 26 of Set 1 | codrington
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | san cristobal
# Processing Record 29 of Set 1 | port macquarie
# Processing Record 30 of Set 1 | yar-sale
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | brzeg dolny
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | lethbridge
# Processing Record 39 of Set 1 | poum
# Processing Record 40 of Set 1 | kandrian
# Processing Record 41 of Set 1 | atambua
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | dingtao
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | hengshui
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 2 | mallama
# City not found. Skipping...
# Processing Record 2 of Set 2 | tosham
# Processing Record 3 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 2 | ende
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | broken hill
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | samarai
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | bantry
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | liepaja
# Processing Record 17 of Set 2 | nuuk
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | vao
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | kibakwe
# Processing Record 23 of Set 2 | wagar
# Processing Record 24 of Set 2 | itamaraca
# Processing Record 25 of Set 2 | bilma
# Processing Record 26 of Set 2 | coulihaut
# City not found. Skipping...
# Processing Record 27 of Set 2 | mingshui
# Processing Record 28 of Set 2 | hohhot
# Processing Record 29 of Set 2 | biskamzha
# Processing Record 30 of Set 2 | the valley
# Processing Record 31 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 2 | novopokrovka
# Processing Record 33 of Set 2 | hofn
# Processing Record 34 of Set 2 | mareeba
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | bonfim
# Processing Record 37 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | sehwan
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 44 of Set 2 | san luis
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | tura
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | ambulu
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | awbari
# Processing Record 2 of Set 3 | agnibilekrou
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | catalina foothills
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | kurilsk
# Processing Record 8 of Set 3 | seredka
# Processing Record 9 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 3 | santa maria del oro
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | chatsu
# City not found. Skipping...
# Processing Record 13 of Set 3 | jinchang
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | voloshka
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | pidhorodna
# Processing Record 22 of Set 3 | sept-iles
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | berlevag
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | egvekinot
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | te anau
# Processing Record 30 of Set 3 | salinopolis
# Processing Record 31 of Set 3 | bathsheba
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | karratha
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | waitara
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | yerbogachen
# Processing Record 39 of Set 3 | ahuimanu
# Processing Record 40 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 3 | rudnya
# Processing Record 42 of Set 3 | tarsus
# Processing Record 43 of Set 3 | chik
# Processing Record 44 of Set 3 | nyrob
# Processing Record 45 of Set 3 | leh
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | bonthe
# Processing Record 48 of Set 3 | tahoua
# Processing Record 49 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | georgiyevka
# Processing Record 3 of Set 4 | paramonga
# Processing Record 4 of Set 4 | butaritari
# Processing Record 5 of Set 4 | galle
# Processing Record 6 of Set 4 | pekalongan
# Processing Record 7 of Set 4 | komsomolskiy
# Processing Record 8 of Set 4 | samarkand
# Processing Record 9 of Set 4 | lar
# Processing Record 10 of Set 4 | juegang
# Processing Record 11 of Set 4 | hokitika
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | vicuna
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | smithers
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | fare
# Processing Record 18 of Set 4 | yarada
# Processing Record 19 of Set 4 | dubbo
# Processing Record 20 of Set 4 | sri aman
# Processing Record 21 of Set 4 | gazli
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | ouesso
# Processing Record 24 of Set 4 | alim
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | luganville
# Processing Record 29 of Set 4 | nalut
# Processing Record 30 of Set 4 | lamont
# Processing Record 31 of Set 4 | singaraja
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | faya
# Processing Record 34 of Set 4 | pandan
# Processing Record 35 of Set 4 | sabya
# Processing Record 36 of Set 4 | hilo
# Processing Record 37 of Set 4 | barrow
# Processing Record 38 of Set 4 | devonport
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | bremerton
# Processing Record 41 of Set 4 | avera
# Processing Record 42 of Set 4 | alice springs
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | moree
# Processing Record 45 of Set 4 | solnechnyy
# Processing Record 46 of Set 4 | araouane
# Processing Record 47 of Set 4 | boden
# Processing Record 48 of Set 4 | utete
# Processing Record 49 of Set 4 | kuytun
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | twentynine palms
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | san joaquin
# Processing Record 9 of Set 5 | lima
# Processing Record 10 of Set 5 | quang ngai
# Processing Record 11 of Set 5 | havoysund
# Processing Record 12 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | ust-barguzin
# Processing Record 15 of Set 5 | pauini
# Processing Record 16 of Set 5 | mersing
# Processing Record 17 of Set 5 | yenotayevka
# Processing Record 18 of Set 5 | loandjili
# Processing Record 19 of Set 5 | alyangula
# Processing Record 20 of Set 5 | jamestown
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | warwick
# Processing Record 24 of Set 5 | ruidoso
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | formosa
# Processing Record 27 of Set 5 | dzaoudzi
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | qixingtai
# Processing Record 30 of Set 5 | puerto escondido
# Processing Record 31 of Set 5 | tateyama
# Processing Record 32 of Set 5 | morgan city
# Processing Record 33 of Set 5 | sadasivpet
# Processing Record 34 of Set 5 | chicama
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | sinnamary
# Processing Record 38 of Set 5 | porto novo
# Processing Record 39 of Set 5 | mackay
# Processing Record 40 of Set 5 | viedma
# Processing Record 41 of Set 5 | woodward
# Processing Record 42 of Set 5 | candolim
# Processing Record 43 of Set 5 | bonavista
# Processing Record 44 of Set 5 | poltavka
# Processing Record 45 of Set 5 | fukue
# Processing Record 46 of Set 5 | kongolo
# Processing Record 47 of Set 5 | sao filipe
# Processing Record 48 of Set 5 | iralaya
# Processing Record 49 of Set 5 | paidha
# Processing Record 50 of Set 5 | ribeira grande
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | ninghai
# Processing Record 3 of Set 6 | eureka
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | narasannapeta
# Processing Record 6 of Set 6 | port hueneme
# Processing Record 7 of Set 6 | shache
# Processing Record 8 of Set 6 | cervo
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | zaragoza
# Processing Record 11 of Set 6 | krosno odrzanskie
# Processing Record 12 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 6 | necochea
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | rudnogorsk
# Processing Record 16 of Set 6 | faanui
# Processing Record 17 of Set 6 | klyuchi
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | saint-joseph
# Processing Record 20 of Set 6 | neiafu
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | munsingen
# Processing Record 23 of Set 6 | galesong
# Processing Record 24 of Set 6 | cockburn town
# Processing Record 25 of Set 6 | saint anthony
# Processing Record 26 of Set 6 | innisfail
# Processing Record 27 of Set 6 | kouroussa
# Processing Record 28 of Set 6 | imbituba
# Processing Record 29 of Set 6 | san patricio
# Processing Record 30 of Set 6 | angra
# City not found. Skipping...
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | nara
# Processing Record 33 of Set 6 | san rafael
# Processing Record 34 of Set 6 | price
# Processing Record 35 of Set 6 | saskylakh
# Processing Record 36 of Set 6 | naze
# Processing Record 37 of Set 6 | kamenka
# Processing Record 38 of Set 6 | okitipupa
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | bandundu
# Processing Record 42 of Set 6 | zaoyang
# Processing Record 43 of Set 6 | jackson
# Processing Record 44 of Set 6 | flin flon
# Processing Record 45 of Set 6 | kazachinskoye
# Processing Record 46 of Set 6 | kawalu
# Processing Record 47 of Set 6 | sembe
# Processing Record 48 of Set 6 | ukiah
# Processing Record 49 of Set 6 | salamanca
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 2 of Set 7 | kimbe
# Processing Record 3 of Set 7 | noumea
# Processing Record 4 of Set 7 | pumiao
# Processing Record 5 of Set 7 | eyemouth
# Processing Record 6 of Set 7 | christchurch
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | urusha
# Processing Record 9 of Set 7 | darhan
# Processing Record 10 of Set 7 | gubkinskiy
# Processing Record 11 of Set 7 | san
# Processing Record 12 of Set 7 | aksu
# Processing Record 13 of Set 7 | shirvan
# Processing Record 14 of Set 7 | randvere
# City not found. Skipping...
# Processing Record 15 of Set 7 | altay
# Processing Record 16 of Set 7 | tilichiki
# Processing Record 17 of Set 7 | san pedro
# Processing Record 18 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | whitianga
# Processing Record 22 of Set 7 | nizhneangarsk
# Processing Record 23 of Set 7 | hambantota
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | flic en flac
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | dunedin
# Processing Record 28 of Set 7 | itarema
# Processing Record 29 of Set 7 | marzuq
# Processing Record 30 of Set 7 | san quintin
# Processing Record 31 of Set 7 | yulara
# Processing Record 32 of Set 7 | waspan
# Processing Record 33 of Set 7 | nizwa
# Processing Record 34 of Set 7 | matamoros
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | nanortalik
# Processing Record 37 of Set 7 | matehuala
# Processing Record 38 of Set 7 | burnie
# Processing Record 39 of Set 7 | awjilah
# Processing Record 40 of Set 7 | nome
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | odiongan
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | colan
# Processing Record 45 of Set 7 | dikson
# Processing Record 46 of Set 7 | tonj
# Processing Record 47 of Set 7 | murgab
# Processing Record 48 of Set 7 | sioux lookout
# Processing Record 49 of Set 7 | balikpapan
# Processing Record 50 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 8 | syamzha
# Processing Record 2 of Set 8 | rantepao
# Processing Record 3 of Set 8 | horki
# Processing Record 4 of Set 8 | acari
# Processing Record 5 of Set 8 | gari
# Processing Record 6 of Set 8 | camocim
# Processing Record 7 of Set 8 | black diamond
# Processing Record 8 of Set 8 | qingdao
# Processing Record 9 of Set 8 | cap malheureux
# Processing Record 10 of Set 8 | fairview
# Processing Record 11 of Set 8 | north platte
# Processing Record 12 of Set 8 | hyderabad
# Processing Record 13 of Set 8 | brae
# Processing Record 14 of Set 8 | taltal
# Processing Record 15 of Set 8 | manjacaze
# Processing Record 16 of Set 8 | condado
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | cotonou
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | kirakira
# Processing Record 21 of Set 8 | lovozero
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | donji milanovac
# Processing Record 24 of Set 8 | los llanos de aridane
# Processing Record 25 of Set 8 | manakara
# Processing Record 26 of Set 8 | qiongshan
# Processing Record 27 of Set 8 | erzin
# Processing Record 28 of Set 8 | plouzane
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | kushima
# Processing Record 31 of Set 8 | floro
# Processing Record 32 of Set 8 | vaitape
# Processing Record 33 of Set 8 | bam
# Processing Record 34 of Set 8 | esperance
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | kjollefjord
# Processing Record 37 of Set 8 | svetlogorsk
# Processing Record 38 of Set 8 | dong hoi
# Processing Record 39 of Set 8 | malazgirt
# Processing Record 40 of Set 8 | burriana
# Processing Record 41 of Set 8 | biltine
# Processing Record 42 of Set 8 | algiers
# Processing Record 43 of Set 8 | palmer
# Processing Record 44 of Set 8 | storforshei
# Processing Record 45 of Set 8 | dali
# Processing Record 46 of Set 8 | aquiraz
# Processing Record 47 of Set 8 | turan
# Processing Record 48 of Set 8 | trincomalee
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | santiago de cao
# Processing Record 1 of Set 9 | imperia
# Processing Record 2 of Set 9 | touros
# Processing Record 3 of Set 9 | rapid valley
# Processing Record 4 of Set 9 | rio gallegos
# Processing Record 5 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 9 | nadym
# Processing Record 7 of Set 9 | kishi
# Processing Record 8 of Set 9 | lebu
# Processing Record 9 of Set 9 | bentiu
# Processing Record 10 of Set 9 | severnyy
# Processing Record 11 of Set 9 | tezu
# Processing Record 12 of Set 9 | yuancheng
# Processing Record 13 of Set 9 | halacho
# Processing Record 14 of Set 9 | meadow lake
# Processing Record 15 of Set 9 | bereznik
# Processing Record 16 of Set 9 | nago
# Processing Record 17 of Set 9 | portland
# Processing Record 18 of Set 9 | hualmay
# Processing Record 19 of Set 9 | borda da mata
# Processing Record 20 of Set 9 | tiznit
# Processing Record 21 of Set 9 | podosinovets
# Processing Record 22 of Set 9 | vilhena
# Processing Record 23 of Set 9 | shasta lake
# Processing Record 24 of Set 9 | ocos
# Processing Record 25 of Set 9 | verkhoyansk
# Processing Record 26 of Set 9 | bella union
# Processing Record 27 of Set 9 | tyukalinsk
# Processing Record 28 of Set 9 | diaz
# Processing Record 29 of Set 9 | chulym
# Processing Record 30 of Set 9 | china
# Processing Record 31 of Set 9 | ucluelet
# Processing Record 32 of Set 9 | somers
# Processing Record 33 of Set 9 | warrnambool
# Processing Record 34 of Set 9 | mocuba
# Processing Record 35 of Set 9 | nata
# Processing Record 36 of Set 9 | katghora
# Processing Record 37 of Set 9 | tecpan
# Processing Record 38 of Set 9 | maragogi
# Processing Record 39 of Set 9 | vostok
# Processing Record 40 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 9 | san jose
# Processing Record 42 of Set 9 | axim
# Processing Record 43 of Set 9 | lac-megantic
# Processing Record 44 of Set 9 | lorengau
# Processing Record 45 of Set 9 | wamba
# Processing Record 46 of Set 9 | garowe
# Processing Record 47 of Set 9 | samandag
# Processing Record 48 of Set 9 | moura
# Processing Record 49 of Set 9 | mineral wells
# Processing Record 50 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 10 | yumen
# Processing Record 2 of Set 10 | adzope
# Processing Record 3 of Set 10 | saint-jean-port-joli
# Processing Record 4 of Set 10 | pacific grove
# Processing Record 5 of Set 10 | port elizabeth
# Processing Record 6 of Set 10 | cordoba
# Processing Record 7 of Set 10 | senneterre
# Processing Record 8 of Set 10 | barsovo
# Processing Record 9 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 10 | guozhen
# Processing Record 11 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 10 | purgstall
# Processing Record 13 of Set 10 | vila franca do campo
# Processing Record 14 of Set 10 | fuling
# Processing Record 15 of Set 10 | severobaykalsk
# Processing Record 16 of Set 10 | buchanan
# Processing Record 17 of Set 10 | luderitz
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | vilyuysk
# Processing Record 20 of Set 10 | nouadhibou
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | kulhudhuffushi
# Processing Record 23 of Set 10 | grindavik
# Processing Record 24 of Set 10 | ust-maya
# Processing Record 25 of Set 10 | prado
# Processing Record 26 of Set 10 | vestmannaeyjar
# Processing Record 27 of Set 10 | annau
# Processing Record 28 of Set 10 | dembi dolo
# Processing Record 29 of Set 10 | sapernoye
# Processing Record 30 of Set 10 | san vicente
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 | sechelt
# Processing Record 33 of Set 10 | alexandria
# Processing Record 34 of Set 10 | westport
# Processing Record 35 of Set 10 | morro bay
# Processing Record 36 of Set 10 | pamfila
# Processing Record 37 of Set 10 | pontian kecil
# Processing Record 38 of Set 10 | saint pete beach
# Processing Record 39 of Set 10 | nelson bay
# Processing Record 40 of Set 10 | jacareacanga
# Processing Record 41 of Set 10 | alberdi
# Processing Record 42 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 43 of Set 10 | las vegas
# Processing Record 44 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 10 | narsaq
# Processing Record 47 of Set 10 | lander
# Processing Record 48 of Set 10 | inyonga
# Processing Record 49 of Set 10 | northam
# Processing Record 50 of Set 10 | kloulklubed
# Processing Record 1 of Set 11 | roswell
# Processing Record 2 of Set 11 | byron bay
# Processing Record 3 of Set 11 | leiva
# Processing Record 4 of Set 11 | ajka
# Processing Record 5 of Set 11 | maradi
# Processing Record 6 of Set 11 | yatou
# Processing Record 7 of Set 11 | petatlan
# Processing Record 8 of Set 11 | dryden
# Processing Record 9 of Set 11 | la uribe
# City not found. Skipping...
# Processing Record 10 of Set 11 | west richland
# Processing Record 11 of Set 11 | guerrero negro
# Processing Record 12 of Set 11 | kosh-agach
# Processing Record 13 of Set 11 | turka
# Processing Record 14 of Set 11 | rudbar
# Processing Record 15 of Set 11 | canon city
# Processing Record 16 of Set 11 | karasjok
# Processing Record 17 of Set 11 | panacan
# Processing Record 18 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | mount gambier
# Processing Record 21 of Set 11 | borsa
# Processing Record 22 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 11 | rayachoti
# Processing Record 24 of Set 11 | powell
# Processing Record 25 of Set 11 | santa rosa
# Processing Record 26 of Set 11 | nantucket
# Processing Record 27 of Set 11 | priladozhskiy
# Processing Record 28 of Set 11 | kalmunai
# Processing Record 29 of Set 11 | kismayo
# Processing Record 30 of Set 11 | baykit
# Processing Record 31 of Set 11 | nampa
# Processing Record 32 of Set 11 | dauphin
# Processing Record 33 of Set 11 | manta
# Processing Record 34 of Set 11 | farmington
# Processing Record 35 of Set 11 | tuxtepec
# Processing Record 36 of Set 11 | tarata
# Processing Record 37 of Set 11 | bela
# Processing Record 38 of Set 11 | harboore
# Processing Record 39 of Set 11 | talnakh
# Processing Record 40 of Set 11 | olafsvik
# Processing Record 41 of Set 11 | xuddur
# Processing Record 42 of Set 11 | ostrovnoy
# Processing Record 43 of Set 11 | umm lajj
# Processing Record 44 of Set 11 | cururupu
# Processing Record 45 of Set 11 | tocopilla
# Processing Record 46 of Set 11 | povoa de varzim
# Processing Record 47 of Set 11 | emerald
# Processing Record 48 of Set 11 | saint-denis
# Processing Record 49 of Set 11 | inuvik
# Processing Record 50 of Set 11 | porbandar
# Processing Record 1 of Set 12 | saldanha
# Processing Record 2 of Set 12 | simao
# Processing Record 3 of Set 12 | karaman
# Processing Record 4 of Set 12 | el alto
# Processing Record 5 of Set 12 | warmbad
# Processing Record 6 of Set 12 | lenger
# Processing Record 7 of Set 12 | kerema
# Processing Record 8 of Set 12 | chernyshevskiy
# Processing Record 9 of Set 12 | ati
# Processing Record 10 of Set 12 | upington
# Processing Record 11 of Set 12 | kysyl-syr
# Processing Record 12 of Set 12 | inhambane
# Processing Record 13 of Set 12 | vieques
# Processing Record 14 of Set 12 | khoy
# Processing Record 15 of Set 12 | talara
# Processing Record 16 of Set 12 | lumeje
# Processing Record 17 of Set 12 | thenzawl
# Processing Record 18 of Set 12 | poso
# Processing Record 19 of Set 12 | xifeng
# Processing Record 20 of Set 12 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 21 of Set 12 | mahon
# Processing Record 22 of Set 12 | katsuura
# Processing Record 23 of Set 12 | nioro
# Processing Record 24 of Set 12 | xicotencatl
# Processing Record 25 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 26 of Set 12 | plettenberg bay
# Processing Record 27 of Set 12 | botwood
# Processing Record 28 of Set 12 | namatanai
# Processing Record 29 of Set 12 | beisfjord
# Processing Record 30 of Set 12 | gryazi
# Processing Record 31 of Set 12 | yen bai
# Processing Record 32 of Set 12 | savannakhet
# Processing Record 33 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 12 | kidal
# Processing Record 35 of Set 12 | adre
# Processing Record 36 of Set 12 | moanda
# Processing Record 37 of Set 12 | georgetown
# Processing Record 38 of Set 12 | bayburt
# Processing Record 39 of Set 12 | mishkino
# Processing Record 40 of Set 12 | tursunzoda
# Processing Record 41 of Set 12 | tashigang
# Processing Record 42 of Set 12 | linqu
# Processing Record 43 of Set 12 | rezina
# Processing Record 44 of Set 12 | shenjiamen
# Processing Record 45 of Set 12 | andenes
# Processing Record 46 of Set 12 | khasan
# Processing Record 47 of Set 12 | abu samrah
# Processing Record 48 of Set 12 | gat
# Processing Record 49 of Set 12 | redmond
# Processing Record 50 of Set 12 | alihe
# Processing Record 1 of Set 13 | terra santa
# Processing Record 2 of Set 13 | verkh-usugli
# Processing Record 3 of Set 13 | panjab
# Processing Record 4 of Set 13 | bosaso
# Processing Record 5 of Set 13 | tapejara
# Processing Record 6 of Set 13 | potam
# Processing Record 7 of Set 13 | batagay-alyta
# Processing Record 8 of Set 13 | langfang
# Processing Record 9 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 13 | prince rupert
# Processing Record 11 of Set 13 | waipawa
# Processing Record 12 of Set 13 | terekli-mekteb
# Processing Record 13 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | vokhtoga
# Processing Record 16 of Set 13 | tanout
# Processing Record 17 of Set 13 | champerico
# Processing Record 18 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | paris
# Processing Record 20 of Set 13 | aykhal
# Processing Record 21 of Set 13 | richards bay
# Processing Record 22 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 13 | piopio
# Processing Record 24 of Set 13 | yanam
# Processing Record 25 of Set 13 | milkovo
# Processing Record 26 of Set 13 | yinchuan
# Processing Record 27 of Set 13 | chanika
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | listvyanskiy
# Processing Record 30 of Set 13 | poronaysk
# Processing Record 31 of Set 13 | bolshevik
# Processing Record 32 of Set 13 | chumikan
# Processing Record 33 of Set 13 | kungurtug
# Processing Record 34 of Set 13 | sombrerete
# Processing Record 35 of Set 13 | hirara
# Processing Record 36 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 13 | belvidere
# Processing Record 38 of Set 13 | flagstaff
# Processing Record 39 of Set 13 | labuan
# Processing Record 40 of Set 13 | lundazi
# Processing Record 41 of Set 13 | ageyevo
# Processing Record 42 of Set 13 | beira
# Processing Record 43 of Set 13 | kokopo
# Processing Record 44 of Set 13 | zhanaozen
# Processing Record 45 of Set 13 | mechanicsville
# Processing Record 46 of Set 13 | falkenberg
# Processing Record 47 of Set 13 | haapiti
# Processing Record 48 of Set 13 | chingola
# Processing Record 49 of Set 13 | drochtersen
# Processing Record 50 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 14 | pisco
# Processing Record 2 of Set 14 | novyye burasy
# Processing Record 3 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 14 | jiazi
# Processing Record 5 of Set 14 | kuala krai
# City not found. Skipping...
# Processing Record 6 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 14 | deder
# Processing Record 8 of Set 14 | baruun-urt
# Processing Record 9 of Set 14 | manggar
# Processing Record 10 of Set 14 | mopipi
# Processing Record 11 of Set 14 | portobelo
# Processing Record 12 of Set 14 | junagarh
# Processing Record 13 of Set 14 | ixtapa
# Processing Record 14 of Set 14 | dalbandin
# Processing Record 15 of Set 14 | port-gentil
# Processing Record 16 of Set 14 | jining
# Processing Record 17 of Set 14 | saint-augustin
# Processing Record 18 of Set 14 | rio cuarto
# Processing Record 19 of Set 14 | laguna
# Processing Record 20 of Set 14 | baracoa
# Processing Record 21 of Set 14 | urumqi
# Processing Record 22 of Set 14 | dukat
# Processing Record 23 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 14 | snyder
# Processing Record 26 of Set 14 | mulege
# Processing Record 27 of Set 14 | owerri
# Processing Record 28 of Set 14 | kutum
# Processing Record 29 of Set 14 | belaya gora
# Processing Record 30 of Set 14 | pemangkat
# Processing Record 31 of Set 14 | huanren
# Processing Record 32 of Set 14 | sikea
# City not found. Skipping...
# Processing Record 33 of Set 14 | nisia floresta
# Processing Record 34 of Set 14 | coolum beach
# Processing Record 35 of Set 14 | tulun
# Processing Record 36 of Set 14 | leninsk-kuznetskiy
# Processing Record 37 of Set 14 | clyde river
# Processing Record 38 of Set 14 | sovetskaya gavan
# Processing Record 39 of Set 14 | puri
# Processing Record 40 of Set 14 | krasnoye
# Processing Record 41 of Set 14 | barentu
# Processing Record 42 of Set 14 | doha
# Processing Record 43 of Set 14 | bocanda
# Processing Record 44 of Set 14 | gizo
# Processing Record 45 of Set 14 | itoman
# Processing Record 46 of Set 14 | lodja
# Processing Record 47 of Set 14 | agirish
# Processing Record 48 of Set 14 | tazmalt
# Processing Record 49 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 14 | teacapan
# Processing Record 1 of Set 15 | texas city
# Processing Record 2 of Set 15 | general roca
# Processing Record 3 of Set 15 | port moresby
# Processing Record 4 of Set 15 | znamenskoye
# Processing Record 5 of Set 15 | khatassy
# Processing Record 6 of Set 15 | jeremie
# Processing Record 7 of Set 15 | meulaboh
# Processing Record 8 of Set 15 | carsamba
# Processing Record 9 of Set 15 | visby
# Processing Record 10 of Set 15 | kathmandu
# Processing Record 11 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 12 of Set 15 | irtyshskiy
# Processing Record 13 of Set 15 | matto
# City not found. Skipping...
# Processing Record 14 of Set 15 | nanakuli
# Processing Record 15 of Set 15 | chapais
# Processing Record 16 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 15 | takoradi
# Processing Record 18 of Set 15 | codo
# Processing Record 19 of Set 15 | morondava
# Processing Record 20 of Set 15 | general pico
# Processing Record 21 of Set 15 | darien
# Processing Record 22 of Set 15 | okhotsk
# Processing Record 23 of Set 15 | honjo
# Processing Record 24 of Set 15 | athabasca
# Processing Record 25 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 15 | abu kamal
# Processing Record 27 of Set 15 | honiara
# Processing Record 28 of Set 15 | bol
# Processing Record 29 of Set 15 | walvis bay
# Processing Record 30 of Set 15 | new braunfels
# Processing Record 31 of Set 15 | altagracia de orituco
# Processing Record 32 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 15 | chom bung
# City not found. Skipping...
# Processing Record 35 of Set 15 | zhicheng
# Processing Record 36 of Set 15 | banda aceh
# Processing Record 37 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 38 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 39 of Set 15 | angoche
# Processing Record 40 of Set 15 | les cayes
# Processing Record 41 of Set 15 | srednekolymsk
# Processing Record 42 of Set 15 | antofagasta
# Processing Record 43 of Set 15 | uruzgan
# Processing Record 44 of Set 15 | pembroke
# Processing Record 45 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 15 | lircay
# Processing Record 49 of Set 15 | gorontalo
# Processing Record 50 of Set 15 | fengkou
# Processing Record 1 of Set 16 | verkhnevilyuysk
# Processing Record 2 of Set 16 | vestmanna
# Processing Record 3 of Set 16 | pecos
# Processing Record 4 of Set 16 | sinegorskiy
# Processing Record 5 of Set 16 | owando
# Processing Record 6 of Set 16 | erenhot
# Processing Record 7 of Set 16 | sola
# Processing Record 8 of Set 16 | conde
# Processing Record 9 of Set 16 | ketchikan
# Processing Record 10 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 16 | bundaberg
# Processing Record 12 of Set 16 | shimoda
# Processing Record 13 of Set 16 | toyo
# Processing Record 14 of Set 16 | savelugu
# Processing Record 15 of Set 16 | santa cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Cherskiy  68.7500  161.3000     72.75        31          21
# 1           Port Alfred -33.5906   26.8910     53.19        79           0
# 2               Mayumba  -3.4320   10.6554     71.94        86          57
# 3           New Norfolk -42.7826  147.0587     47.70        86          96
# 4                 Kapaa  22.0752 -159.3190     80.58        75          40
# 5              Victoria  22.2855  114.1577     93.38        64          10
# 6          Punta Arenas -53.1500  -70.9167     39.31        81          75
# 7               Aklavik  68.2191 -135.0107     49.75        72         100
# 8  San Carlos Del Zulia   9.0000  -71.9135     72.45        94          97
# 9                 Bowen -20.0167  148.2333     70.34        78         100
#
#    Wind Speed Country                 Date Current Description
# 0       14.50      RU  2022-08-01 07:20:14          few clouds
# 1        1.99      ZA  2022-08-01 07:20:15           clear sky
# 2        5.73      GA  2022-08-01 07:20:15       broken clouds
# 3        3.00      AU  2022-08-01 07:20:15       moderate rain
# 4       20.71      US  2022-08-01 07:20:16    scattered clouds
# 5       10.00      HK  2022-08-01 07:20:16           clear sky
# 6        5.75      CL  2022-08-01 07:20:17       broken clouds
# 7       12.12      CA  2022-08-01 07:20:17     overcast clouds
# 8        4.43      VE  2022-08-01 07:20:17     overcast clouds
# 9       13.22      AU  2022-08-01 07:20:18     overcast clouds

# %%
new_column_order=['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Current Description']
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0              Cherskiy      RU  2022-08-01 07:20:14  68.7500  161.3000
# 1           Port Alfred      ZA  2022-08-01 07:20:15 -33.5906   26.8910
# 2               Mayumba      GA  2022-08-01 07:20:15  -3.4320   10.6554
# 3           New Norfolk      AU  2022-08-01 07:20:15 -42.7826  147.0587
# 4                 Kapaa      US  2022-08-01 07:20:16  22.0752 -159.3190
# 5              Victoria      HK  2022-08-01 07:20:16  22.2855  114.1577
# 6          Punta Arenas      CL  2022-08-01 07:20:17 -53.1500  -70.9167
# 7               Aklavik      CA  2022-08-01 07:20:17  68.2191 -135.0107
# 8  San Carlos Del Zulia      VE  2022-08-01 07:20:17   9.0000  -71.9135
# 9                 Bowen      AU  2022-08-01 07:20:18 -20.0167  148.2333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     72.75        31          21       14.50          few clouds
# 1     53.19        79           0        1.99           clear sky
# 2     71.94        86          57        5.73       broken clouds
# 3     47.70        86          96        3.00       moderate rain
# 4     80.58        75          40       20.71    scattered clouds
# 5     93.38        64          10       10.00           clear sky
# 6     39.31        81          75        5.75       broken clouds
# 7     49.75        72         100       12.12     overcast clouds
# 8     72.45        94          97        4.43     overcast clouds
# 9     70.34        78         100       13.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
